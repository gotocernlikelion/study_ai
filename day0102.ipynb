# %%
#Python Warning off
import warnings
warnings.filterwarnings('ignore')

#TF warning off
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10

# %%
i = 1
hap = 0
while i <= 100:
    hap = hap + i 
    i = i+1
hap
# Out:
# 5050

# %%
hap = 0 
for i in range(1,101):
    hap = i + hap 
print(hap)
# Out:
# 5050

# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
"""df means Data Frame """
df = pd.read_excel("datasets/titanic.xls")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.boxplot()

# %%
df['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
f, ax = plt.subplots(1,2,figsize=(12,6))
"""f는 피규어 정보를 담고 있는데, 여기서는 안썼음. 그래서 _,ax 로 두어도 됨. 참고로 ax 는 아래 두 칸을 의미함. 그래서 ax[0], ax[1]로 쓸 수 있음"""

df['survived'].value_counts().plot.pie(explode=[0,0.1],autopct="%.2f%%",ax=ax[0])
""" 위에서 밸류 카운트 한걸 파이 차트로 그린다는 의미 """

sns.countplot('survived',data=df, ax=ax[1])
""" 위에서 밸류 카운트 한 걸 카운트플롯 한다는 의미 """
# Out:
# ' 위에서 밸류 카운트 한 걸 카운트플롯 한다는 의미 '

# %%
df['age'].hist(bins=20,figsize=(18,8),grid=False)
"""bins는 단위"""
# Out:
# 'bins는 단위'

# %%
df['age'].hist(bins=60,figsize=(18,8),grid=False)

# %%
df['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
df.groupby('pclass').mean()
# Out:
#         survived        age     sibsp     parch       fare        body
# pclass
# 1       0.619195  39.159918  0.436533  0.365325  87.508992  162.828571
# 2       0.429603  29.506705  0.393502  0.368231  21.179196  167.387097
# 3       0.255289  24.816367  0.568406  0.400564  13.302889  155.818182

# %%
df.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),linewidths=0.01, square=True, cmap=plt.cm.viridis, linecolor='white', annot=True)

# %%
df['age_cat'] = pd.cut(df['age'],bins=[0,10,20,50,100], include_lowest=True, labels=['baby','teenage','adult','old'])
# include_lowest는 최소를 포함한다는 의미, 즉 0~9, 10~19 ... 이런식으로 자르겠다는 의미 """

df
#bins에서 5개를 줬으니, 총 4개의 구간으로 잘림. 따라서 labels에는 4개 항목이 들어가야함"""
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    1
# 1          1         1                   Allison, Master. Hudson Trevor    0
# 2          1         0                     Allison, Miss. Helen Loraine    1
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
# ...      ...       ...                                              ...  ...
# 1301       3         0                             Youseff, Mr. Gerious    0
# 1304       3         0                             Zabour, Miss. Hileni    1
# 1306       3         0                        Zakarian, Mr. Mapriededer    0
# 1307       3         0                              Zakarian, Mr. Ortin    0
# 1308       3         0                               Zimmerman, Mr. Leo    0
#
# ...

# %%
plt.figure(figsize=[12,4])

plt.subplot(131) 
#""" 131에서 첫번째 수는 '행', 두번째 수는 '열', 세 번째 수는 '몇번째' 를 의미한다. """

sns.barplot('pclass','survived',data=df)

plt.subplot(132)

sns.barplot('age_cat', 'survived', data=df)

plt.subplot(133)

sns.barplot('sex', 'survived', data=df)

# %%
import seaborn as sns
sns.set(style="ticks")

df_iris = sns.load_dataset("iris")
sns.pairplot(df_iris, hue="species")

# %%
_, ax = plt.subplots(1,2, figsize=[12,6])
sns.countplot('sex',data=df, ax = ax[0])

sns.countplot('sex', hue='survived', data=df,ax=ax[1])
""" hue는 기준이다"""

"""['survived'].value_counts().plot.pie(explode=[0,0.1],autopct="%.2f%%",ax=ax[1])"""
# Out:
# '[\'survived\'].value_counts().plot.pie(explode=[0,0.1],autopct="%.2f%%",ax=ax[1])'

# %%
df = pd.read_excel("datasets/titanic.xls")

tmp = []
for i in df['sex']:
    if i == 'female':
        tmp.append(1)
    else:
        tmp.append(0)     
        
df['sex'] = tmp
df
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    1
# 1          1         1                   Allison, Master. Hudson Trevor    0
# 2          1         0                     Allison, Miss. Helen Loraine    1
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    1
# 1305       3         0                            Zabour, Miss. Thamine    1
# 1306       3         0                        Zakarian, Mr. Mapriededer    0
# 1307       3         0                              Zakarian, Mr. Ortin    0
# 1308       3         0                               Zimmerman, Mr. Leo    0
#
# ...

# %%
df = df[
    df['age'].notnull()
]
""" missing date 결측치를 버리고 남은 값만 모으기 """

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1046 non-null   int64
#  1   survived   1046 non-null   int64
#  2   name       1046 non-null   object
#  3   sex        1046 non-null   int64
#  4   age        1046 non-null   float64
#  5   sibsp      1046 non-null   int64
#  6   parch      1046 non-null   int64
#  7   ticket     1046 non-null   object
#  8   fare       1045 non-null   float64
#  9   cabin      272 non-null    object
#  10  embarked   1044 non-null   object
#  11  boat       417 non-null    object
#  12  body       120 non-null    float64
#  13  home.dest  685 non-null    object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 122.6+ KB

# %%
df[ df['fare'].isnull() ]
""" True 인 값만 나온다 """
# Out:
# ' True 인 값만 나온다 '

# %%
df['fare'].isnull()
""" 항목별 True False여부만 나온다 """
# Out:
# ' 항목별 True False여부만 나온다 '

# %%
df = df [ df['fare'].notnull() ]
df
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    1
# 1          1         1                   Allison, Master. Hudson Trevor    0
# 2          1         0                     Allison, Miss. Helen Loraine    1
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    0
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1
# ...      ...       ...                                              ...  ...
# 1301       3         0                             Youseff, Mr. Gerious    0
# 1304       3         0                             Zabour, Miss. Hileni    1
# 1306       3         0                        Zakarian, Mr. Mapriededer    0
# 1307       3         0                              Zakarian, Mr. Ortin    0
# 1308       3         0                               Zimmerman, Mr. Leo    0
#
# ...

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1045 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1045 non-null   int64
#  1   survived   1045 non-null   int64
#  2   name       1045 non-null   object
#  3   sex        1045 non-null   int64
#  4   age        1045 non-null   float64
#  5   sibsp      1045 non-null   int64
#  6   parch      1045 non-null   int64
#  7   ticket     1045 non-null   object
#  8   fare       1045 non-null   float64
#  9   cabin      272 non-null    object
#  10  embarked   1043 non-null   object
#  11  boat       417 non-null    object
#  12  body       119 non-null    float64
#  13  home.dest  685 non-null    object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 122.5+ KB

# %%
#        pclass, sex, age, slisp, parch, fare
# index : 0       3    4    5      6      8

x_data = df.values[: , [0,3,4,5,6,8]] # values는 숫자만 따옴
x_data
# Out:
# array([[1, 1, 29.0, 0, 0, 211.3375],
#        [1, 0, 0.9167, 1, 2, 151.55],
#        [1, 1, 2.0, 1, 2, 151.55],
#        ...,
#        [3, 0, 26.5, 0, 0, 7.225],
#        [3, 0, 27.0, 0, 0, 7.225],
#        [3, 0, 29.0, 0, 0, 7.875]], dtype=object)

# %%
y_data = df.values[:,[1]] #생존여부 확인
y_data
# Out:
# array([[1],
#        [1],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=object)

# %%
import random
random.randint(1,100) # 시드가 고정되지 않아서 (현재 시간), 실행해줄 때마다
# Out:
# 93

# %%
import random
random.seed(69) # 시드 고정하면, 결과가 항상 같게 유지됨
random.randint(1,100)
# Out:
# 88

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x_data, y_data, test_size=0.1, random_state=7)
# x_data와 y_data가 각각 x _train x_test와 y_train, y_test로 스플릿 됨. 
# seed를 고정시키면 재연성이 올라감

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((940, 6), (940, 1), (105, 6), (105, 1))

# %%
X_train[0]
# Out:
# array([3, 1, 45.0, 0, 0, 7.75], dtype=object)

# %%
y_train[0]
# Out:
# array([0], dtype=object)

# %%
# keras import 

import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential #Sequential은 뇌 혹은 건물을 의미
from keras.layers import Dense #Dense는 한 층을 의미

# %%
model = Sequential()
model.add(Dense(128, input_shape = (6, ), activation = 'relu')) #128개 뉴런, 6개의 input 요소, 다음 층으로는 relu함수(1층)
model.add(Dense(128, activation = 'relu')) #(2층)
model.add(Dense(1, activation = 'sigmoid'))#마지막 층의 경우 1개의 뉴런 보유, sigmoid 함수 사용 (3층)
#모델 설계

# %%
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['accuracy'])
#모델 설정

# %%
hist = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 500) #epochs: 학습 회수
#훈련
# Out:
# Train on 940 samples, validate on 105 samples
# Epoch 1/500
# 940/940 [==============================] - 0s 276us/step - loss: 0.3062 - acc: 0.6234 - val_loss: 0.2164 - val_acc: 0.7143
# Epoch 2/500
# 940/940 [==============================] - 0s 23us/step - loss: 0.2285 - acc: 0.6574 - val_loss: 0.1949 - val_acc: 0.7619
# Epoch 3/500
# 940/940 [==============================] - 0s 24us/step - loss: 0.2135 - acc: 0.6809 - val_loss: 0.1877 - val_acc: 0.7810
# Epoch 4/500
# 940/940 [==============================] - 0s 23us/step - loss: 0.2132 - acc: 0.6872 - val_loss: 0.1995 - val_acc: 0.7333
# Epoch 5/500
# 940/940 [==============================] - 0s 22us/step - loss: 0.2155 - acc: 0.6809 - val_loss: 0.1924 - val_acc: 0.7048
# Epoch 6/500
# 940/940 [==============================] - 0s 23us/step - loss: 0.1974 - acc: 0.7085 - val_loss: 0.1767 - val_acc: 0.7905
# Epoch 7/500
# ...

# %%
plt.figure(figsize = (12, 8))
plt.plot(hist.history['loss']) #훈련 비용
plt.plot(hist.history['val_loss']) #검증 비용
plt.plot(hist.history['acc']) #훈련 정확도
plt.plot(hist.history['val_acc']) #검증 정확도
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'])
plt.show()

# %%
#디카프리오는 살 수 있었나? 
# 3등실, 남성, 19살, 형제없고 부모 없음, 싼 표(5 dollar) 

dicaprio = np.array([3,0,19,0,0,5]).reshape(1,6)
#reshape 2차원 구조인 1x6 행렬로 바꿔줌
model.predict(dicaprio)
# Out:
# array([[0.10663828]], dtype=float32)

# %%
#여주인공 윈슬릿은?
#1등실, 여성:1, 17살, 형제 1명, 부모 2명, 비싼표(100 dollar)

winslet = np.array([1,1,17,1,2,100]).reshape(1,6)
model.predict(winslet)
# Out:
# array([[0.9995043]], dtype=float32)
